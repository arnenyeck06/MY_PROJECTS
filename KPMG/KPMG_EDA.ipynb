# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile
from datetime import datetime
import datetime as dt

# %%
tdf = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'Transactions')

# %%
tdf
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
### The column"product first sold date" need to be converted into Date datatype.

# %%
tdf['product_first_sold_date'].head(5)
# Out:
# 0    41245.0
# 1    41701.0
# 2    36361.0
# 3    36145.0
# 4    42226.0
# Name: product_first_sold_date, dtype: float64

# %%
tdf['product_first_sold_date'] = pd.to_datetime(tdf['product_first_sold_date'], unit = 's' )
tdf['product_first_sold_date']
# Out:
# 0       1970-01-01 11:27:25
# 1       1970-01-01 11:35:01
# 2       1970-01-01 10:06:01
# 3       1970-01-01 10:02:25
# 4       1970-01-01 11:43:46
#                 ...
# 19995   1970-01-01 10:30:23
# 19996   1970-01-01 09:52:40
# 19997   1970-01-01 11:13:30
# 19998   1970-01-01 10:36:56
# 19999   1970-01-01 10:05:34
# Name: product_first_sold_date, Length: 20000, dtype: datetime64[ns]

# %%
tdf.head(20)
# Out:
#     transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                1           2         2950       2017-02-25           0.0
# 1                2           3         3120       2017-05-21           1.0
# 2                3          37          402       2017-10-16           0.0
# 3                4          88         3135       2017-08-31           0.0
# 4                5          78          787       2017-10-01           1.0
# 5                6          25         2339       2017-03-08           1.0
# 6                7          22         1542       2017-04-21           1.0
# 7                8          15         2459       2017-07-15           0.0
# 8                9          67         1305       2017-08-10           0.0
# 9               10          12         3262       2017-08-30           1.0
# 10              11           5         1986       2017-01-17           0.0
# ...

# %%
tdf.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
## We can keep or delete the null values depending on the purpose of the study.

# %%
tdf.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %%
## checking for dupplicates
tdf.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool

# %% [markdown]
# ### CHECKING COLUMNS

# %%
tdf.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
tdf['transaction_date'].value_counts()
# Out:
# 2017-02-14    82
# 2017-08-18    82
# 2017-10-15    76
# 2017-01-31    73
# 2017-12-19    71
#               ..
# 2017-01-12    38
# 2017-12-07    37
# 2017-03-29    36
# 2017-09-25    35
# 2017-10-19    32
# Name: transaction_date, Length: 364, dtype: int64

# %%
tdf['transaction_id'].value_counts()
# Out:
# 1        1
# 13331    1
# 13338    1
# 13337    1
# 13336    1
#         ..
# 6667     1
# 6666     1
# 6665     1
# 6664     1
# 20000    1
# Name: transaction_id, Length: 20000, dtype: int64

# %%
tdf['product_id'].value_counts()
# Out:
# 0      1378
# 3       354
# 1       311
# 35      268
# 38      267
#        ...
# 71      137
# 8       136
# 16      136
# 100     130
# 47      121
# Name: product_id, Length: 101, dtype: int64

# %%
tdf['customer_id'].value_counts()
# Out:
# 2183    14
# 2476    14
# 1068    14
# 1672    13
# 2912    13
#         ..
# 898      1
# 2352     1
# 1846     1
# 3279     1
# 1757     1
# Name: customer_id, Length: 3494, dtype: int64

# %%
tdf['online_order'].value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
tdf['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
tdf['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
tdf['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
tdf['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
tdf['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
tdf['list_price'].value_counts()
# Out:
# 2091.47    465
# 1403.50    396
# 71.49      274
# 1231.15    235
# 1890.39    233
#           ...
# 56.21        1
# 126.36       1
# 1300.96      1
# 1697.27      1
# 867.92       1
# Name: list_price, Length: 296, dtype: int64

# %%
tdf['standard_cost'].value_counts()
# Out:
# 388.920000    465
# 954.820000    396
# 53.620000     274
# 161.600000    235
# 260.140000    233
#              ...
# 151.960000    124
# 206.350000    114
# 312.735016      1
# 270.299988      1
# 667.400024      1
# Name: standard_cost, Length: 103, dtype: int64

# %%
tdf['product_first_sold_date'].value_counts()
# Out:
# 1970-01-01 09:24:39    234
# 1970-01-01 11:24:24    229
# 1970-01-01 10:30:23    227
# 1970-01-01 11:04:40    222
# 1970-01-01 10:36:56    220
#                       ...
# 1970-01-01 11:37:28    169
# 1970-01-01 11:46:44    168
# 1970-01-01 11:38:42    166
# 1970-01-01 10:27:39    163
# 1970-01-01 09:36:26    162
# Name: product_first_sold_date, Length: 100, dtype: int64

# %% [markdown]
# ### NEW CUSOTMER LIST EXPLORATION

# %%
ncl = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'NewCustomerList')
ncl
# Out:
# /var/folders/bb/g_j9n1j52yg5jykb0rcgyh6w0000gn/T/ipykernel_49221/904572282.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   ncl = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'NewCustomerList')
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# ...

# %%
ncl.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
## drop unnmaed columns.
ncl = ncl.loc[:, ~ncl.columns.str.contains('^Unnamed')]
ncl
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
ncl.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
ncl.isna().sum() ## checking for missing values
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
ncl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
## Checking for duplicates values
ncl.duplicated().sum()
# Out:
# 0

# %%
ncl.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
## Explore columns
ncl['first_name'].value_counts()
# Out:
# Rozamond     3
# Dorian       3
# Mandie       3
# Inglebert    2
# Ricki        2
#             ..
# Diego        1
# Lucilia      1
# Eddy         1
# Caron        1
# Sylas        1
# Name: first_name, Length: 940, dtype: int64

# %%
ncl['last_name'].value_counts()
# Out:
# Sissel       2
# Minshall     2
# Borsi        2
# Shoesmith    2
# Sturch       2
#             ..
# O'Moylane    1
# Axtens       1
# Moxted       1
# Conrad       1
# Duffill      1
# Name: last_name, Length: 961, dtype: int64

# %%
ncl['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %% [markdown]
# ##We can replace U by "Unknown"

# %%
ncl['gender'] = ncl['gender'].str.replace('U', 'Unknown')
# Out:
# /var/folders/bb/g_j9n1j52yg5jykb0rcgyh6w0000gn/T/ipykernel_49221/2488975389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ncl['gender'] = ncl['gender'].str.replace('U', 'Unknown')

# %%
ncl['gender'].value_counts()
# Out:
# Female     513
# Male       470
# Unknown     17
# Name: gender, dtype: int64

# %%
ncl['past_3_years_bike_related_purchases'].value_counts()
# Out:
# 60    20
# 59    18
# 42    17
# 70    17
# 11    16
#       ..
# 19     5
# 9      5
# 92     5
# 85     4
# 20     3
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64

# %%
ncl['DOB'].value_counts()
# Out:
# 1998-02-05    2
# 1978-01-15    2
# 1977-11-08    2
# 1951-11-28    2
# 1979-07-28    2
#              ..
# 1945-08-08    1
# 1943-08-27    1
# 1999-10-24    1
# 1976-01-24    1
# 1955-10-02    1
# Name: DOB, Length: 958, dtype: int64

# %%
ncl['job_title'].value_counts()
# Out:
# Associate Professor         15
# Environmental Tech          14
# Software Consultant         14
# Chief Design Engineer       13
# Assistant Manager           12
#                             ..
# Accountant II                1
# Programmer IV                1
# Administrative Officer       1
# Accounting Assistant III     1
# Web Developer I              1
# Name: job_title, Length: 184, dtype: int64

# %%
ncl['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
ncl['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
ncl['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
ncl['deceased_indicator'].value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %%
ncl['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
ncl['tenure'].value_counts()
# Out:
# 9     79
# 13    74
# 11    68
# 10    63
# 12    61
# 5     60
# 7     60
# 17    59
# 15    58
# 8     55
# 14    54
# 16    49
# 6     45
# 4     36
# 18    36
# 19    34
# 3     26
# 21    24
# 20    22
# 2     15
# 22    12
# 1      8
# 0      2
# Name: tenure, dtype: int64

# %%
ncl['address'].value_counts()
# Out:
# 45 Shopko Center             1
# 77608 Donald Center          1
# 7 Elgar Hill                 1
# 36506 Bartillon Point        1
# 8 Scott Drive                1
#                             ..
# 102 Charing Cross Terrace    1
# 5 Trailsway Avenue           1
# 23694 Leroy Place            1
# 53 Memorial Street           1
# 21875 Grover Drive           1
# Name: address, Length: 1000, dtype: int64

# %%
ncl['postcode'].value_counts()
# Out:
# 2145    9
# 2232    9
# 2750    7
# 3977    7
# 2148    7
#        ..
# 2576    1
# 2479    1
# 3065    1
# 2762    1
# 4215    1
# Name: postcode, Length: 522, dtype: int64

# %%
ncl['country'].value_counts()
# Out:
# Australia    1000
# Name: country, dtype: int64

# %% [markdown]
# ### CUSTOMER DEMOGRAPHIC EDA

# %%
cdf = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'CustomerDemographic')
cdf.head(10)
# Out:
# /var/folders/bb/g_j9n1j52yg5jykb0rcgyh6w0000gn/T/ipykernel_49221/1051000774.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   cdf = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'CustomerDemographic')
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
# 5            6            Curr  Duckhouse    Male
# 6            7            Fina     Merali  Female
# 7            8             Rod      Inder    Male
# 8            9            Mala       Lind  Female
# 9           10        Fiorenze    Birdall  Female
#
# ...

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
## Check for missing values
cdf.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
## We will delete the missing values.
cdf = cdf.dropna()

# %%
cdf.head(10)
# Out:
#     customer_id first_name  last_name  gender  \
# 0             1    Laraine  Medendorp       F
# 1             2        Eli    Bockman    Male
# 2             3      Arlin     Dearle    Male
# 8             9       Mala       Lind  Female
# 9            10   Fiorenze    Birdall  Female
# 11           12    Sawyere   Flattman    Male
# 12           13   Gabriele   Norcross    Male
# 13           14   Rayshell   Kitteman  Female
# 14           15     Erroll     Radage    Male
# 18           19     Sorcha     Keyson  Female
#
#     past_3_years_bike_related_purchases        DOB  \
# 0                                    93 1953-10-12
# 1                                    81 1980-12-16
# 2                                    61 1954-01-20
# 8                                    97 1973-03-10
# 9                                    49 1988-10-11
# 11                                   58 1994-07-21
# 12                                   38 1955-02-15
# ...

# %%
## Check for duplicates.
cdf.duplicated().sum()
# Out:
# 0

# %%
## check columns
cdf.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
cdf['first_name'].value_counts()
# Out:
# Tobe       5
# Osgood     4
# Gerome     4
# Lindsay    4
# Jayson     3
#           ..
# Bing       1
# Curran     1
# Leisha     1
# Woody      1
# Blanch     1
# Name: first_name, Length: 2234, dtype: int64

# %%
cdf['gender'].value_counts()
# Out:
# Female    1366
# Male      1262
# F            1
# Femal        1
# Name: gender, dtype: int64

# %% [markdown]
# ##The column 'gender' has inconsistencies.

# %%
cdf['gender']= cdf['gender'].replace('Femaleemale', 'Female').replace('Femaleemal', 'Female')
# Out:
# /var/folders/bb/g_j9n1j52yg5jykb0rcgyh6w0000gn/T/ipykernel_49221/3560780821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['gender']= cdf['gender'].replace('Femaleemale', 'Female').replace('Femaleemal', 'Female')

# %%
cdf['gender'].value_counts()
# Out:
# Female    1368
# Male      1262
# Name: gender, dtype: int64

# %%
cdf['tenure'].value_counts()
# Out:
# 7.0     157
# 5.0     155
# 12.0    154
# 16.0    148
# 8.0     147
# 10.0    143
# 9.0     141
# 18.0    140
# 11.0    137
# 6.0     135
# 14.0    130
# 13.0    122
# 4.0     122
# 17.0    116
# 3.0     111
# 19.0    110
# 15.0    107
# 1.0     106
# 2.0     102
# 20.0     67
# 21.0     40
# 22.0     40
# Name: tenure, dtype: int64

# %%
cdf['owns_car'].value_counts()
# Out:
# Yes    1361
# No     1269
# Name: owns_car, dtype: int64

# %%
cdf['job_industry_category'].value_counts()
# Out:
# Manufacturing         635
# Financial Services    626
# Health                496
# Retail                278
# Property              222
# IT                    119
# Entertainment         110
# Argiculture            91
# Telecommunications     53
# Name: job_industry_category, dtype: int64

# %% [markdown]
# ### CUSTOMER ADDRESS EDA

# %%
cadf = pd.read_excel('/Users/arnenyeck/Desktop/Repositories/files/KPMG_RawData.xlsx', sheet_name = 'CustomerAddress')
cadf
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
cadf.isna().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
cadf['address']
# Out:
# 0              060 Morning Avenue
# 1             6 Meadow Vale Court
# 2              0 Holy Cross Court
# 3             17979 Del Mar Point
# 4                9 Oakridge Court
#                   ...
# 3994              1482 Hauk Trail
# 3995    57042 Village Green Point
# 3996       87 Crescent Oaks Alley
# 3997             8194 Lien Street
# 3998              320 Acker Drive
# Name: address, Length: 3999, dtype: object

# %% [markdown]
# ### MERGING ALL CUSTOMERS TABLES

# %%
cdf['customer_id'].iloc[-1]
# Out:
# 3997

# %%
## adding 'customer id' to the table 'new_customer'
ncl.insert(0, 'customer_id', range(3998, 3998 + len(ncl)))

# %%
ncl.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         3998    Chickie    Brister    Male
# 1         3999      Morly     Genery    Male
# 2         4000    Ardelis  Forrester  Female
# 3         4001     Lucine      Stutt  Female
# 4         4002    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# ...

# %%
## Merging customer demographic with customer address.
cdf = pd.merge(cdf, cadf, how = 'left', on = 'customer_id')
cdf
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 3               9       Mala       Lind  Female
# 4              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 2625         3993       Andi    Dumelow  Female
# 2626         3994    Stephie      Byars  Female
# 2627         3995      Rusty     Iapico    Male
# 2628         3996    Rosalia   Halgarth  Female
# 2629         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      97 1973-03-10
# 4                                      49 1988-10-11
# ...                                   ...        ...
# ...

# %%
new_df = pd.concat([cdf, ncl])
new_df
# Out:
#      customer_id first_name  last_name  gender  \
# 0              1    Laraine  Medendorp  Female
# 1              2        Eli    Bockman    Male
# 2              3      Arlin     Dearle    Male
# 3              9       Mala       Lind  Female
# 4             10   Fiorenze    Birdall  Female
# ..           ...        ...        ...     ...
# 995         4993  Ferdinand  Romanetti    Male
# 996         4994       Burk    Wortley    Male
# 997         4995   Melloney      Temby  Female
# 998         4996     Dickie    Cubbini    Male
# 999         4997      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases        DOB  \
# 0                                     93 1953-10-12
# 1                                     81 1980-12-16
# 2                                     61 1954-01-20
# 3                                     97 1973-03-10
# 4                                     49 1988-10-11
# ..                                   ...        ...
# ...
